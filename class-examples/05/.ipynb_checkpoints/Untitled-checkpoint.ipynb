# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

data = pd.DataFrame({
    "hours":[1,2,3,4,5,6,7,8],
    "score":[50,55,65,70,80,85,90,95]
})

X = data[["hours"]]
y = data["score"]

#print(X)
#print(y)

X_train,X_test,y_train,y_test = train_test_split(
    X,y,test_size=0.2,random_state=1
)

model = LinearRegression()
model.fit(X_train, y_train)

pred = model.predict(X_test)

print("MAE: ", mean_absolute_error(y_test, pred))
print("MSE: ",mean_squared_error(y_test, pred))



hours = [[6]]
print(model.predict(hours)[0])
# Out:
# MAE:  2.5465838509316754
# MSE:  7.535396010956358
# 84.53416149068323
# C:\Users\msade\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# Common imports
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer

from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

from sklearn.metrics import (
    accuracy_score, confusion_matrix, classification_report,
    mean_absolute_error, mean_squared_error, r2_score,
    precision_score, recall_score, f1_score
)

def make_housing(n=700, seed=2):
    rng = np.random.default_rng(seed)
    size = rng.normal(1600, 350, n)
    beds = rng.integers(1, 6, n)
    city = rng.choice(["Toronto","Montreal","Vancouver","Calgary"], size=n)
    base_price = 180*size + 35000*beds
    bump = pd.Series(city).map({"Toronto":200000,"Vancouver":250000,"Montreal":80000,"Calgary":60000}).to_numpy()
    price = base_price + bump + rng.normal(0, 30000, n)
    X = pd.DataFrame({"size_sqft": size, "beds": beds, "city": city})
    return X, price

X, y = make_housing(n=700 , seed=205)


#print(X)
#print(y)

X_num = X[["size_sqft", "beds"]]

#display(X_num)

X_train, X_test, y_train, y_test = train_test_split(
            X_num, y,test_size=0.30,random_state=205
        )

model = LinearRegression()
model.fit(X_train, y_train)

pred = model.predict(X_test)


house = [[2000,3]]

print("Prediction : ", model.predict(house)[0])


print("MAE: ", mean_absolute_error(y_test, pred))
print("MSE: ",mean_squared_error(y_test, pred))

mse =mean_squared_error(y_test, pred)
rmse = np.sqrt(mse)

print(rmse)
# Out:
# Prediction :  605515.031638031
# MAE:  79636.1246510085
# MSE:  7519401024.595938
# 86714.4799015478
# C:\Users\msade\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# Common imports
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer

from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

from sklearn.metrics import (
    accuracy_score, confusion_matrix, classification_report,
    mean_absolute_error, mean_squared_error, r2_score,
    precision_score, recall_score, f1_score
)

def make_housing(n=700, seed=2):
    rng = np.random.default_rng(seed)
    size = rng.normal(1600, 350, n)
    beds = rng.integers(1, 6, n)
    city = rng.choice(["Toronto","Montreal","Vancouver","Calgary"], size=n)
    base_price = 180*size + 35000*beds
    bump = pd.Series(city).map({"Toronto":200000,"Vancouver":250000,"Montreal":80000,"Calgary":60000}).to_numpy()
    price = base_price + bump + rng.normal(0, 30000, n)
    X = pd.DataFrame({"size_sqft": size, "beds": beds, "city": city})
    return X, price

X, y = make_housing(n=700 , seed=205)


#print(X)
#print(y)

X_num = X[["size_sqft", "beds", "city"]]

#display(X_num)

X_train, X_test, y_train, y_test = train_test_split(
            X_num, y,test_size=0.30,random_state=205
        )

numeric_features = ["size_sqft", "beds"]
categorical_features = ["city"]

prepocessor = ColumnTransformer(
    transformers=[
        ("num", StandardScaler(), numeric_features ),
        ("cat", OneHotEncoder(), categorical_features )   
    ]    
)



model = Pipeline([

    ("prepocessor", prepocessor  ),
    ("regression", LinearRegression())
])



model.fit(X_train, y_train)

pred = model.predict(X_test)


house = pd.DataFrame({

    "size_sqft": [2000],
    "beds": [3],
    "city": ["Vancouver"]
    
})

print("Prediction : ", model.predict(house)[0])


print("MAE: ", mean_absolute_error(y_test, pred))
print("MSE: ",mean_squared_error(y_test, pred))

mse =mean_squared_error(y_test, pred)
rmse = np.sqrt(mse)

print(rmse)
# Out:
# Prediction :  716704.3522823988
# MAE:  22202.22724751711
# MSE:  783152596.6580113
# 27984.863706261127

# %%
import pandas as pd 
data = pd.read_csv("housing_sample.csv")
display(data)



X = data[["size_sqft", "beds", "city"]]
y = data["price"]



X_train, X_test, y_train, y_test = train_test_split(
           X, y,test_size=0.30,random_state=205
        )

numeric_features = ["size_sqft", "beds"]
categorical_features = ["city"]

prepocessor = ColumnTransformer(
    transformers=[
        ("num", StandardScaler(), numeric_features ),
        ("cat", OneHotEncoder(), categorical_features )   
    ]    
)



model = Pipeline([

    ("prepocessor", prepocessor  ),
    ("regression", LinearRegression())
])



model.fit(X_train, y_train)

pred = model.predict(X_test)


house = pd.DataFrame({

    "size_sqft": [2000],
    "beds": [3],
    "city": ["Vancouver"]
    
})

print("Prediction : ", model.predict(house)[0])


print("MAE: ", mean_absolute_error(y_test, pred))
print("MSE: ",mean_squared_error(y_test, pred))

mse =mean_squared_error(y_test, pred)
rmse = np.sqrt(mse)

print(rmse)
# Out:
#     size_sqft  beds       city   price
# 0        1800     3    Toronto  620000
# 1        2200     4    Toronto  760000
# 2        1500     2   Montreal  430000
# 3        1950     3    Calgary  500000
# 4        2500     5  Vancouver  890000
# 5        1700     3   Montreal  470000
# 6        2100     4    Calgary  560000
# 7        1400     2    Toronto  540000
# 8        2800     5  Vancouver  960000
# 9        1600     3    Calgary  455000
# 10       2300     4   Montreal  610000
# 11       1900     3  Vancouver  735000
# Prediction :  774941.1764705882
# MAE:  23382.352941176505
# MSE:  777555363.3218
# 27884.679724210568
